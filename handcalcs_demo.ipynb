# %%
import handcalcs.render
import forallpeople as si
from scipy.integrate import quad
si.environment('structural', top_level=True)

# %%
# %%render params
# a_z = 10*m/s**2
# mass = 500*kg
# Out:
# \[
# \begin{aligned}
# a_{z} &= 5.000\ \mathrm{kN/m} \;
#  &\mathrm{mass} &= 500.000\ \mathrm{kg} \;
# \end{aligned}
# \]

# %%
# %%render
# F_z = a_z*mass
# Out:
# \[
# \begin{aligned}
# F_{z} &= a_{z} \cdot \mathrm{mass}  = 5.000\ \mathrm{kN/m} \cdot 500.000\ \mathrm{kg} &= 2500000.000\ \mathrm{kg}^{2} \cdot \mathrm{s}^{-2}
# \end{aligned}
# \]

# %%
v_max = 10 * (si.m/si.s)
def f(t):
    return v_max *t

# %%
# %%render
# a=2
# b=6
# z, err_z=quad(f, a, b)
# distance = z * si.m
# Out:
# \[
# \begin{aligned}
# a &= 2 \;
# \\[10pt]
# b &= 6 \;
# \\[10pt]
# z ,\  \mathrm{err}_{z} &= \int_{ a } ^ { b } v_{max} \cdot t \; dt ,\  0.000  = \int_{ 2 } ^ { 6 } 10.000\ \mathrm{m} \cdot \mathrm{s}^{-1} \cdot t \; dt &= 160.000
# \\[10pt]
# \mathrm{distance} &= z \cdot \mathrm{si.m}  = 160.000 \cdot si.m &= 160.000\ \mathrm{m}
# \end{aligned}
# \]
