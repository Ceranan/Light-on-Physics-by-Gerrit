# %%
import handcalcs.render
import numpy as np
from scipy.constants import speed_of_light, Boltzmann, pi

from math import pi, sqrt, exp
import forallpeople as si
from scipy.integrate import quad
si.environment('default', top_level=True)
handcalcs.set_option('use_scientific_notation', True)
handcalcs.set_option('display_precision', 6)

# %% [markdown]
# Dipole Trap Depth Question 9.15 in Atomic Physics by Foot
#
# $U_{dipole} = \frac{\hbar \Gamma^2 I}{8\delta I_{sat}}$

# %%
# %%render params
# w_0 = 780 * 1e-9 *m#transition wavelength
# w = 1064*1e-09 *m #laser wavelength
# Rb_transition_freq  = 2*pi * 6.065 *1e6 *Hz #transition frequency Gamma
# laser_power = 1 *W#Watt
# laser_waist = 10e-6 *m #laser waist
# c = 300000000 *m/s
# I_sat = 16.7 *W/m**2 #saturation intensity
# mass_Rb = 1.443*1e-25 *kg # kg mass of Rb 87
# hbar = 1.054571817e-34 * (kg * m**2 / s)
# k_B = 1.380649e-23 * si.kg * si.m**2 / (si.s**2 * si.K)
# g=9.8*m/s**2
# Out:
# $$
# \begin{aligned}
# w_{0} &= 780.000000\ \mathrm{nm} \; \;\textrm{(transition wavelength)}
#  &w &= 1.064000\ \mathrm{μm} \; \;\textrm{(laser wavelength)}
#  &\mathrm{Rb}_{transition_{freq}} &= 38.107519\ \mathrm{MHz} \; \;\textrm{(transition frequency Gamma)}
# \\
#  \mathrm{laser}_{power} &= 1.000000\ \mathrm{W} \; \;\textrm{(Watt)}
#  &\mathrm{laser}_{waist} &= 10.000000\ \mathrm{μm} \; \;\textrm{(laser waist)}
#  &c &= 300000000.000000\ \mathrm{m} \cdot \mathrm{s}^{-1} \;
# \\
#  I_{sat} &= 16.700000\ \mathrm{kg} \cdot \mathrm{s}^{-3} \; \;\textrm{(saturation intensity)}
#  &\mathrm{mass}_{Rb} &= 144.300000\ \mathrm{yg} \; \;\textrm{(kg mass of Rb 87)}
#  &\mathrm{hbar} &= 0.000000\ \mathrm{kg} \cdot \mathrm{m}^{2} \cdot \mathrm{s}^{-1} \;
# \\
#  k_{B} &= 0.000000\ \mathrm{kg} \cdot \mathrm{m}^{2} \cdot \mathrm{s}^{-2} \cdot \mathrm{K}^{-1} \;
#  &g &= 9.800000\ \mathrm{m} \cdot \mathrm{s}^{-2} \;
# \end{aligned}
# $$

# %%
detuning = 2*pi*c*(1/w_0 - 1/w)

# %%
# %%render
# detuning = 2*pi*c*(1/w_0 - 1/w) #wont allow proper units
# Out:
# $$
# \begin{aligned}
# \mathrm{detuning} &= 2 \cdot \pi \cdot c \cdot \left( \frac{ 1 }{ w_{0} } - \frac{ 1 }{ w } \right)  = 2 \cdot 3.141593 \cdot 300000000.000000\ \mathrm{m} \cdot \mathrm{s}^{-1} \cdot \left( \frac{ 1 }{ 780.000000\ \mathrm{nm} } - \frac{ 1 }{ 1.064000\ \mathrm{μm} } \right) &= 645.034929\ \mathrm{THz} \; \;\textrm{(wont allow proper units)}
# \end{aligned}
# $$

# %%
# %%render
# I_over_I_sat = 2*laser_power/(pi * laser_waist**2)/I_sat #ratio of $\frac{I}{I_{sat}}$
# Out:
# $$
# \begin{aligned}
# I_{over_{I_{sat}}} &= 2 \cdot \frac{ \mathrm{laser}_{power} }{ \pi \cdot \left( \mathrm{laser}_{waist} \right) ^{ 2 } } \cdot \frac{1} { I_{sat} } \\&= 2 \cdot \frac{ 1.000000\ \mathrm{W} }{ 3.141593 \cdot \left( 10.000000\ \mathrm{μm} \right) ^{ 2 } } \cdot \frac{1} { 16.700000\ \mathrm{kg} \cdot \mathrm{s}^{-3} } \\&= 381209444.531486 \; \;\textrm{(ratio of $\frac{I}{I_{sat}}$)}\\
# \end{aligned}
# $$

# %%
U_dipole = hbar*Rb_transition_freq**2*I_over_I_sat/(8*detuning)

# %%
C = U_dipole * laser_waist**2

# %%
print(U_dipole.value, 'J')
print(U_dipole.value/Boltzmann*1000, 'mK')
# Out:
# 1.1313264484216582e-26 J
# 0.8194164109934228 mK

# %% [markdown]
# Now find the ratio of the size of the horizontal and longitudinal extent of the dipole trap. This is just isoenergy line?

# %%
# %%render
# dz_dr = sqrt(2) * pi * laser_waist / w
# Out:
# $$
# \begin{aligned}
# \mathrm{dz}_{dr} &= \sqrt { 2 } \cdot \pi \cdot \frac{ \mathrm{laser}_{waist} }{ w }  = \sqrt { 2 } \cdot 3.141593 \cdot \frac{ 10.000000\ \mathrm{μm} }{ 1.064000\ \mathrm{μm} } &= 41.756419
# \end{aligned}
# $$

# %%
print(dz_dr, 'times larger in longitudinal coordinate than transverse state.')
# Out:
# 41.75641859171397 times larger in longitudinal coordinate than transverse state.

# %% [markdown]
# Now find the maximum beam waist where the dipole trap can support Rb atoms against gravity, at the max force of $r=w_0/2$

# %%
# %%render
# F_g = mass_Rb * g
# w_max = (2 * C * exp(-1/2) / F_g)**(1/3)
# Out:
# $$
# \begin{aligned}
# F_{g} &= \mathrm{mass}_{Rb} \cdot g  = 144.300000\ \mathrm{yg} \cdot 9.800000\ \mathrm{m} \cdot \mathrm{s}^{-2} &= 1.414140\ \mathrm{yN}
# \\
# w_{max} &= \left( 2 \cdot C \cdot \frac{ \exp \left( \frac{ \left( - 1 \right) }{ 2 } \right) }{ F_{g} } \right) ^{ \left( \frac{ 1 }{ 3 } \right) } \\&= \left( 2 \cdot 0.000000\ \mathrm{kg} \cdot \mathrm{m}^{4} \cdot \mathrm{s}^{-2} \cdot \frac{ \exp \left( \frac{ \left( - 1 \right) }{ 2 } \right) }{ 1.414140\ \mathrm{yN} } \right) ^{ \left( \frac{ 1 }{ 3 } \right) } \\&= 99.005525\ \mathrm{μm}  \\
# \end{aligned}
# $$
